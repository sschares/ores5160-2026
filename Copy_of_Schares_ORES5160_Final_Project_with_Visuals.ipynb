# %% [markdown]
# <a href="https://colab.research.google.com/github/sschares/ores5160-2026/blob/main/Copy_of_Schares_ORES5160_Final_Project_with_Visuals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
from urllib.request import urlopen, Request

req = Request("https://data.cdc.gov/resource/8xy9-ubqz.json", headers={'User-Agent': 'Mozilla/5.0'})

with urlopen(req) as response:
  source = response.read()

  print(source)
# Out:
# b'[{"round":"1","indicator":"Provider offers telemedicine","group":"Total","subgroup":"Total","sample_size":"6786","response":"Total","percent":"100"}\n,{"round":"1","indicator":"Provider offers telemedicine","group":"Total","subgroup":"Total","response":"Yes","percent":"36.6","standard_error":"0.8"}\n,{"round":"1","indicator":"Provider offers telemedicine","group":"Total","subgroup":"Total","response":"No","percent":"46.9","standard_error":"0.8"}\n,{"round":"1","indicator":"Provider offers telemedicine","group":"Total","subgroup":"Total","response":"Do not know","percent":"5.2","standard_error":"0.4"}\n,{"round":"1","indicator":"Provider offers telemedicine","group":"Total","subgroup":"Total","response":"No usual place of care","percent":"11.3","standard_error":"0.7"}\n,{"round":"1","indicator":"Provider offers telemedicine","group":"Age group","subgroup":"18-44 years","sample_size":"2607","response":"Total","percent":"100"}\n,{"round":"1","indicator":"Provider offers telemedicine","group":"Age group","subgroup":"18-44 years","response":"Yes","percent":"30.2","standard_error":"1.2"}\n,{"round":"1","indicator":"Provider offers telemedicine","group":"Age group","subgroup":"18-44 years","response":"No","percent":"45.9","standard_error":"1.1"}\n,{"round":"1","indicator":"Provider offers telemedicine","group":"Age group","subgroup":"18-44 years","response":"Do not know","percent":"7","standard_error":"0.8"}\n,{"round":"1","indicator":"Provider offers telemedicine","group":"Age group","subgroup":"18-44 years","response":"No usual place of care","percent":"16.9","standard_error":"1.1"}\n,{"round":"1","indicator":"Provider offers telemedicine","group":"Age group","subgroup":"45-64 years","sample_size":"2380","response":"Total","percent":"100"}\n,{"round":"1","indicator":"Provider offers telemedicine","group":"Age group","subgroup":"45-64 years","response":"Yes","percent":"39.8","standard_error":"1.4"}\n,{"round":"1","indicator":"Provider offers telemedicine","group":"Age group","subgroup":"45-64 years","response":"No","percent":"48.5","standard_error":"1.5"}\n,{"round":"1","indicator":"Provider offers telemedicine","group":"Age group","subgroup":"45-64 years","response":"Do not know","percent":"4.1","standard_error":"0.6"}\n,{"round":"1","indicator":"Provider offers telemedicine","group":"Age group","subgroup":"45-64 years","response":"No usual place of care","percent":"7.6","standard_error":"0.7"}\n,{"round":"1","indicator":"Provider offers telemedicine","group":"Age group","subgroup":"65 years and over","sample_size":"1799","response":"Total","percent":"100"}\n,{"round":"1","indicator":"Provider offers telemedicine","group":"Age group","subgroup":"65 years and over","response":"Yes","percent":"45.9","standard_error":"1.3"}\n,{"round":"1","indicator":"Provider offers telemedicine","group":"Age group","subgroup":"65 years and over","response":"No","percent":"46.5","standard_error":"1.3"}\n,{"round":"1","indicator":"Provider offers telemedicine","group":"Age group","subgroup":"65 years and over","response":"Do not know","percent":"2.9","standard_error":"0.5"}\n,{"round":"1","indicator":"Provider offers telemedicine","group":"Age group","subgroup":"65 years and over","response":"No usual place of care","percent":"4.6","standard_error":"0.8"}\n,{"round":"1","indicator":"Provider offers telemedicine","group":"Race/Hispanic origin","subgroup":"White non-Hispanic","sample_size":"4506","response":"Total","percent":"100"}\n,{"round":"1","indicator":"Provider offers telemedicine","group":"Race/Hispanic origin","subgroup":"White non-Hispanic","response":"Yes","percent":"37.4","standard_error":"1.3"}\n,{"round":"1","indicator":"Provider offers telemedicine","group":"Race/Hispanic origin","subgroup":"White non-Hispanic","response":"No","percent":"48.7","standard_error":"1.3"}\n,{"round":"1","indicator":"Provider offers telemedicine","group":"Race/Hispanic origin","subgroup":"White non-Hispanic","response":"Do not know","percent":"4.8","standard_ ...

# %%
data = json.loads(source)
print(type(data))
# Out:
# <class 'list'>

# %%
print(json.dumps(data, indent = 2))
# Out:
# [
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Total",
#     "subgroup": "Total",
#     "sample_size": "6786",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Total",
#     "subgroup": "Total",
#     "response": "Yes",
#     "percent": "36.6",
#     "standard_error": "0.8"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Total",
#     "subgroup": "Total",
#     "response": "No",
#     "percent": "46.9",
#     "standard_error": "0.8"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Total",
#     "subgroup": "Total",
#     "response": "Do not know",
#     "percent": "5.2",
#     "standard_error": "0.4"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Total",
#     "subgroup": "Total",
#     "response": "No usual place of care",
#     "percent": "11.3",
#     "standard_error": "0.7"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "18-44 years",
#     "sample_size": "2607",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "18-44 years",
#     "response": "Yes",
#     "percent": "30.2",
#     "standard_error": "1.2"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "18-44 years",
#     "response": "No",
#     "percent": "45.9",
#     "standard_error": "1.1"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "18-44 years",
#     "response": "Do not know",
#     "percent": "7",
#     "standard_error": "0.8"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "18-44 years",
#     "response": "No usual place of care",
#     "percent": "16.9",
#     "standard_error": "1.1"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "45-64 years",
#     "sample_size": "2380",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "45-64 years",
#     "response": "Yes",
#     "percent": "39.8",
#     "standard_error": "1.4"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "45-64 years",
#     "response": "No",
#     "percent": "48.5",
#     "standard_error": "1.5"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "45-64 years",
#     "response": "Do not know",
#     "percent": "4.1",
#     "standard_error": "0.6"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "45-64 years",
#     "response": "No usual place of care",
#     "percent": "7.6",
#     "standard_error": "0.7"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "65 years and over",
#     "sample_size": "1799",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "65 years and over",
#     "response": "Yes",
#     "percent": "45.9",
#     "standard_error": "1.3"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "65 years and over",
#     "response": "No",
#     "percent": "46.5",
#     "standard_error": "1.3"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "65 years and over",
#     "response": "Do not know",
#     "percent": "2.9",
#     "standard_error": "0.5"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "65 years and over",
#     "response": "No usual place of care",
#     "percent": "4.6",
#     "standard_error": "0.8"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "White non-Hispanic",
#     "sample_size": "4506",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "White non-Hispanic",
#     "response": "Yes",
#     "percent": "37.4",
#     "standard_error": "1.3"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "White non-Hispanic",
#     "response": "No",
#     "percent": "48.7",
#     "standard_error": "1.3"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "White non-Hispanic",
#     "response": "Do not know",
#     "percent": "4.8",
#     "standard_error": "0.5"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "White non-Hispanic",
#     "response": "No usual place of care",
#     "percent": "9.1",
#     "standard_error": "0.7"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "Black non-Hispanic",
#     "sample_size": "811",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "Black non-Hispanic",
#     "response": "Yes",
#     "percent": "38.5",
#     "standard_error": "2.7"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "Black non-Hispanic",
#     "response": "No",
#     "percent": "42.9",
#     "standard_error": "2.1"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "Black non-Hispanic",
#     "response": "Do not know",
#     "percent": "5.8",
#     "standard_error": "0.7"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "Black non-Hispanic",
#     "response": "No usual place of care",
#     "percent": "12.9",
#     "standard_error": "2.2"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "Other non-Hispanic",
#     "sample_size": "529",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "Other non-Hispanic",
#     "response": "Yes",
#     "percent": "34.1",
#     "standard_error": "2.2"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "Other non-Hispanic",
#     "response": "No",
#     "percent": "46.1",
#     "standard_error": "2.6"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "Other non-Hispanic",
#     "response": "Do not know",
#     "suppression": "*"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "Other non-Hispanic",
#     "response": "No usual place of care",
#     "percent": "12.2",
#     "standard_error": "2.4"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "Hispanic",
#     "sample_size": "940",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "Hispanic",
#     "response": "Yes",
#     "percent": "33.4",
#     "standard_error": "2"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "Hispanic",
#     "response": "No",
#     "percent": "43.5",
#     "standard_error": "2.9"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "Hispanic",
#     "response": "Do not know",
#     "percent": "5.2",
#     "standard_error": "1"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "Hispanic",
#     "response": "No usual place of care",
#     "percent": "17.9",
#     "standard_error": "2.6"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Sex",
#     "subgroup": "Male",
#     "sample_size": "2963",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Sex",
#     "subgroup": "Male",
#     "response": "Yes",
#     "percent": "33.4",
#     "standard_error": "1.1"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Sex",
#     "subgroup": "Male",
#     "response": "No",
#     "percent": "48.9",
#     "standard_error": "1.3"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Sex",
#     "subgroup": "Male",
#     "response": "Do not know",
#     "percent": "4.9",
#     "standard_error": "0.5"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Sex",
#     "subgroup": "Male",
#     "response": "No usual place of care",
#     "percent": "12.9",
#     "standard_error": "1"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Sex",
#     "subgroup": "Female",
#     "sample_size": "3823",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Sex",
#     "subgroup": "Female",
#     "response": "Yes",
#     "percent": "39.7",
#     "standard_error": "1"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Sex",
#     "subgroup": "Female",
#     "response": "No",
#     "percent": "45.1",
#     "standard_error": "1"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Sex",
#     "subgroup": "Female",
#     "response": "Do not know",
#     "percent": "5.5",
#     "standard_error": "0.6"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Sex",
#     "subgroup": "Female",
#     "response": "No usual place of care",
#     "percent": "9.8",
#     "standard_error": "1"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Education",
#     "subgroup": "High school graduate or less",
#     "sample_size": "1294",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Education",
#     "subgroup": "High school graduate or less",
#     "response": "Yes",
#     "percent": "35",
#     "standard_error": "1.6"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Education",
#     "subgroup": "High school graduate or less",
#     "response": "No",
#     "percent": "45.7",
#     "standard_error": "1.5"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Education",
#     "subgroup": "High school graduate or less",
#     "response": "Do not know",
#     "percent": "5.1",
#     "standard_error": "0.9"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Education",
#     "subgroup": "High school graduate or less",
#     "response": "No usual place of care",
#     "percent": "14.2",
#     "standard_error": "1.6"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Education",
#     "subgroup": "Some college",
#     "sample_size": "2552",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Education",
#     "subgroup": "Some college",
#     "response": "Yes",
#     "percent": "35.4",
#     "standard_error": "1.5"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Education",
#     "subgroup": "Some college",
#     "response": "No",
#     "percent": "49",
#     "standard_error": "1.2"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Education",
#     "subgroup": "Some college",
#     "response": "Do not know",
#     "percent": "5.2",
#     "standard_error": "0.6"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Education",
#     "subgroup": "Some college",
#     "response": "No usual place of care",
#     "percent": "10.3",
#     "standard_error": "0.7"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Education",
#     "subgroup": "Bachelor's degree or above",
#     "sample_size": "2940",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Education",
#     "subgroup": "Bachelor's degree or above",
#     "response": "Yes",
#     "percent": "39.5",
#     "standard_error": "1"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Education",
#     "subgroup": "Bachelor's degree or above",
#     "response": "No",
#     "percent": "46.3",
#     "standard_error": "1.2"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Education",
#     "subgroup": "Bachelor's degree or above",
#     "response": "Do not know",
#     "percent": "5.3",
#     "standard_error": "0.5"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Education",
#     "subgroup": "Bachelor's degree or above",
#     "response": "No usual place of care",
#     "percent": "8.9",
#     "standard_error": "0.6"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Urbanization",
#     "subgroup": "Metropolitan",
#     "sample_size": "6050",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Urbanization",
#     "subgroup": "Metropolitan",
#     "response": "Yes",
#     "percent": "36.7",
#     "standard_error": "0.9"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Urbanization",
#     "subgroup": "Metropolitan",
#     "response": "No",
#     "percent": "46.2",
#     "standard_error": "0.9"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Urbanization",
#     "subgroup": "Metropolitan",
#     "response": "Do not know",
#     "percent": "5.3",
#     "standard_error": "0.5"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Urbanization",
#     "subgroup": "Metropolitan",
#     "response": "No usual place of care",
#     "percent": "11.8",
#     "standard_error": "0.7"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Urbanization",
#     "subgroup": "Non-Metropolitan",
#     "sample_size": "736",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Urbanization",
#     "subgroup": "Non-Metropolitan",
#     "response": "Yes",
#     "percent": "35.7",
#     "standard_error": "2.3"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Urbanization",
#     "subgroup": "Non-Metropolitan",
#     "response": "No",
#     "percent": "52.2",
#     "standard_error": "2.5"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Urbanization",
#     "subgroup": "Non-Metropolitan",
#     "response": "Do not know",
#     "percent": "4.8",
#     "standard_error": "1.1"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Urbanization",
#     "subgroup": "Non-Metropolitan",
#     "response": "No usual place of care",
#     "percent": "7.2",
#     "standard_error": "1.7"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "One or more chronic conditions",
#     "sample_size": "4082",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "One or more chronic conditions",
#     "response": "Yes",
#     "percent": "45.3",
#     "standard_error": "1.1"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "One or more chronic conditions",
#     "response": "No",
#     "percent": "43.6",
#     "standard_error": "1.1"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "One or more chronic conditions",
#     "response": "Do not know",
#     "percent": "4.1",
#     "standard_error": "0.5"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "One or more chronic conditions",
#     "response": "No usual place of care",
#     "percent": "7.1",
#     "standard_error": "0.6"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "Diagnosed diabetes",
#     "sample_size": "767",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "Diagnosed diabetes",
#     "response": "Yes",
#     "percent": "55.7",
#     "standard_error": "3"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "Diagnosed diabetes",
#     "response": "No",
#     "percent": "34.8",
#     "standard_error": "2.4"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "Diagnosed diabetes",
#     "response": "Do not know",
#     "percent": "3.3",
#     "standard_error": "1"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "Diagnosed diabetes",
#     "response": "No usual place of care",
#     "percent": "6.2",
#     "standard_error": "1.4"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "Diagnosed hypertension",
#     "sample_size": "2421",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "Diagnosed hypertension",
#     "response": "Yes",
#     "percent": "45.6",
#     "standard_error": "1.4"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "Diagnosed hypertension",
#     "response": "No",
#     "percent": "44.8",
#     "standard_error": "1.5"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "Diagnosed hypertension",
#     "response": "Do not know",
#     "percent": "3.7",
#     "standard_error": "0.6"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "Diagnosed hypertension",
#     "response": "No usual place of care",
#     "percent": "5.9",
#     "standard_error": "0.7"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "Current asthma",
#     "sample_size": "696",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "Current asthma",
#     "response": "Yes",
#     "percent": "46",
#     "standard_error": "2.5"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "Current asthma",
#     "response": "No",
#     "percent": "39.9",
#     "standard_error": "2"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "Current asthma",
#     "response": "Do not know",
#     "percent": "5.7",
#     "standard_error": "1.5"
#   },
#   {
#     "round": "1",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "Current asthma",
#     "response": "No usual place of care",
#     "percent": "8.3",
#     "standard_error": "1.6"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Total",
#     "subgroup": "Total",
#     "sample_size": "5972",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Total",
#     "subgroup": "Total",
#     "response": "Yes",
#     "percent": "37.1",
#     "standard_error": "0.7",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Total",
#     "subgroup": "Total",
#     "response": "No",
#     "percent": "48",
#     "standard_error": "0.9",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Total",
#     "subgroup": "Total",
#     "response": "Do not know",
#     "percent": "5.4",
#     "standard_error": "0.4",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Total",
#     "subgroup": "Total",
#     "response": "No usual place of care",
#     "percent": "9.5",
#     "standard_error": "0.7",
#     "significant_1": "1"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "18-44 years",
#     "sample_size": "2212",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "18-44 years",
#     "response": "Yes",
#     "percent": "31.2",
#     "standard_error": "0.9",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "18-44 years",
#     "response": "No",
#     "percent": "47.3",
#     "standard_error": "1.3",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "18-44 years",
#     "response": "Do not know",
#     "percent": "7.5",
#     "standard_error": "0.7",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "18-44 years",
#     "response": "No usual place of care",
#     "percent": "14",
#     "standard_error": "1.3",
#     "significant_1": "1"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "45-64 years",
#     "sample_size": "2079",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "45-64 years",
#     "response": "Yes",
#     "percent": "40.1",
#     "standard_error": "1.3",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "45-64 years",
#     "response": "No",
#     "percent": "48.2",
#     "standard_error": "1.5",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "45-64 years",
#     "response": "Do not know",
#     "percent": "4.7",
#     "standard_error": "0.7",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "45-64 years",
#     "response": "No usual place of care",
#     "percent": "7",
#     "standard_error": "0.8",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "65 years and over",
#     "sample_size": "1681",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "65 years and over",
#     "response": "Yes",
#     "percent": "45.6",
#     "standard_error": "1.7",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "65 years and over",
#     "response": "No",
#     "percent": "49.3",
#     "standard_error": "1.8",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "65 years and over",
#     "response": "Do not know",
#     "percent": "1.8",
#     "standard_error": "0.4",
#     "significant_1": "1"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "65 years and over",
#     "response": "No usual place of care",
#     "percent": "3.4",
#     "standard_error": "0.6",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "White non-Hispanic",
#     "sample_size": "4073",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "White non-Hispanic",
#     "response": "Yes",
#     "percent": "37.9",
#     "standard_error": "1.3",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "White non-Hispanic",
#     "response": "No",
#     "percent": "49.3",
#     "standard_error": "1.4",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "White non-Hispanic",
#     "response": "Do not know",
#     "percent": "4.8",
#     "standard_error": "0.5",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "White non-Hispanic",
#     "response": "No usual place of care",
#     "percent": "8",
#     "standard_error": "0.8",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "Black non-Hispanic",
#     "sample_size": "689",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "Black non-Hispanic",
#     "response": "Yes",
#     "percent": "40",
#     "standard_error": "1.7",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "Black non-Hispanic",
#     "response": "No",
#     "percent": "47.2",
#     "standard_error": "2.2",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "Black non-Hispanic",
#     "response": "Do not know",
#     "percent": "3.4",
#     "standard_error": "0.9",
#     "significant_1": "1"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "Black non-Hispanic",
#     "response": "No usual place of care",
#     "percent": "9.5",
#     "standard_error": "1.7",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "Other non-Hispanic",
#     "sample_size": "461",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "Other non-Hispanic",
#     "response": "Yes",
#     "percent": "34.4",
#     "standard_error": "3.4",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "Other non-Hispanic",
#     "response": "No",
#     "percent": "47.7",
#     "standard_error": "4.2",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "Other non-Hispanic",
#     "response": "Do not know",
#     "percent": "7.9",
#     "standard_error": "1.7"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "Other non-Hispanic",
#     "response": "No usual place of care",
#     "percent": "10.1",
#     "standard_error": "1.8",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "Hispanic",
#     "sample_size": "749",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "Hispanic",
#     "response": "Yes",
#     "percent": "33.1",
#     "standard_error": "2.8",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "Hispanic",
#     "response": "No",
#     "percent": "43.6",
#     "standard_error": "2.6",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "Hispanic",
#     "response": "Do not know",
#     "percent": "8.3",
#     "standard_error": "1.2",
#     "significant_1": "1"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Race/Hispanic origin",
#     "subgroup": "Hispanic",
#     "response": "No usual place of care",
#     "percent": "15",
#     "standard_error": "1.9",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Sex",
#     "subgroup": "Male",
#     "sample_size": "2588",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Sex",
#     "subgroup": "Male",
#     "response": "Yes",
#     "percent": "33.4",
#     "standard_error": "1",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Sex",
#     "subgroup": "Male",
#     "response": "No",
#     "percent": "49.5",
#     "standard_error": "1.2",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Sex",
#     "subgroup": "Male",
#     "response": "Do not know",
#     "percent": "5.7",
#     "standard_error": "0.7",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Sex",
#     "subgroup": "Male",
#     "response": "No usual place of care",
#     "percent": "11.3",
#     "standard_error": "0.9",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Sex",
#     "subgroup": "Female",
#     "sample_size": "3384",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Sex",
#     "subgroup": "Female",
#     "response": "Yes",
#     "percent": "40.5",
#     "standard_error": "0.8",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Sex",
#     "subgroup": "Female",
#     "response": "No",
#     "percent": "46.5",
#     "standard_error": "0.9",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Sex",
#     "subgroup": "Female",
#     "response": "Do not know",
#     "percent": "5.1",
#     "standard_error": "0.6",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Sex",
#     "subgroup": "Female",
#     "response": "No usual place of care",
#     "percent": "7.8",
#     "standard_error": "1",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Education",
#     "subgroup": "High school graduate or less",
#     "sample_size": "1102",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Education",
#     "subgroup": "High school graduate or less",
#     "response": "Yes",
#     "percent": "33.3",
#     "standard_error": "1.4",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Education",
#     "subgroup": "High school graduate or less",
#     "response": "No",
#     "percent": "50.6",
#     "standard_error": "1.7",
#     "significant_1": "1"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Education",
#     "subgroup": "High school graduate or less",
#     "response": "Do not know",
#     "percent": "4.9",
#     "standard_error": "0.8",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Education",
#     "subgroup": "High school graduate or less",
#     "response": "No usual place of care",
#     "percent": "11.2",
#     "standard_error": "1.4",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Education",
#     "subgroup": "Some college",
#     "sample_size": "2224",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Education",
#     "subgroup": "Some college",
#     "response": "Yes",
#     "percent": "37.6",
#     "standard_error": "1.1",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Education",
#     "subgroup": "Some college",
#     "response": "No",
#     "percent": "48.6",
#     "standard_error": "1.2",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Education",
#     "subgroup": "Some college",
#     "response": "Do not know",
#     "percent": "5.1",
#     "standard_error": "0.8",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Education",
#     "subgroup": "Some college",
#     "response": "No usual place of care",
#     "percent": "8.7",
#     "standard_error": "0.8",
#     "significant_1": "1"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Education",
#     "subgroup": "Bachelor's degree or above",
#     "sample_size": "2646",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Education",
#     "subgroup": "Bachelor's degree or above",
#     "response": "Yes",
#     "percent": "40.8",
#     "standard_error": "1.3",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Education",
#     "subgroup": "Bachelor's degree or above",
#     "response": "No",
#     "percent": "44.6",
#     "standard_error": "1.3",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Education",
#     "subgroup": "Bachelor's degree or above",
#     "response": "Do not know",
#     "percent": "6.2",
#     "standard_error": "0.7",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Education",
#     "subgroup": "Bachelor's degree or above",
#     "response": "No usual place of care",
#     "percent": "8.4",
#     "standard_error": "0.6",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Urbanization",
#     "subgroup": "Metropolitan",
#     "sample_size": "5315",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Urbanization",
#     "subgroup": "Metropolitan",
#     "response": "Yes",
#     "percent": "38",
#     "standard_error": "0.7",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Urbanization",
#     "subgroup": "Metropolitan",
#     "response": "No",
#     "percent": "46.9",
#     "standard_error": "0.8",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Urbanization",
#     "subgroup": "Metropolitan",
#     "response": "Do not know",
#     "percent": "5.5",
#     "standard_error": "0.4",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Urbanization",
#     "subgroup": "Metropolitan",
#     "response": "No usual place of care",
#     "percent": "9.7",
#     "standard_error": "0.6",
#     "significant_1": "1"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Urbanization",
#     "subgroup": "Non-Metropolitan",
#     "sample_size": "657",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Urbanization",
#     "subgroup": "Non-Metropolitan",
#     "response": "Yes",
#     "percent": "30.3",
#     "standard_error": "2.7",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Urbanization",
#     "subgroup": "Non-Metropolitan",
#     "response": "No",
#     "percent": "57",
#     "standard_error": "3.6",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Urbanization",
#     "subgroup": "Non-Metropolitan",
#     "response": "Do not know",
#     "suppression": "*"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Urbanization",
#     "subgroup": "Non-Metropolitan",
#     "response": "No usual place of care",
#     "percent": "7.8",
#     "standard_error": "1.8",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "One or more chronic conditions",
#     "sample_size": "3650",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "One or more chronic conditions",
#     "response": "Yes",
#     "percent": "44.5",
#     "standard_error": "0.8",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "One or more chronic conditions",
#     "response": "No",
#     "percent": "45.7",
#     "standard_error": "1.2",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "One or more chronic conditions",
#     "response": "Do not know",
#     "percent": "3.6",
#     "standard_error": "0.4",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "One or more chronic conditions",
#     "response": "No usual place of care",
#     "percent": "6.2",
#     "standard_error": "0.5",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "Diagnosed diabetes",
#     "sample_size": "689",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "Diagnosed diabetes",
#     "response": "Yes",
#     "percent": "55.2",
#     "standard_error": "2.9",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "Diagnosed diabetes",
#     "response": "No",
#     "percent": "36.9",
#     "standard_error": "3.1",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "Diagnosed diabetes",
#     "response": "Do not know",
#     "percent": "2.2",
#     "standard_error": "0.9",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "Diagnosed diabetes",
#     "response": "No usual place of care",
#     "percent": "5.7",
#     "standard_error": "1.4",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "Diagnosed hypertension",
#     "sample_size": "2190",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "Diagnosed hypertension",
#     "response": "Yes",
#     "percent": "47.1",
#     "standard_error": "1.3",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "Diagnosed hypertension",
#     "response": "No",
#     "percent": "44.5",
#     "standard_error": "1.6",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "Diagnosed hypertension",
#     "response": "Do not know",
#     "percent": "3.1",
#     "standard_error": "0.5",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "Diagnosed hypertension",
#     "response": "No usual place of care",
#     "percent": "5.3",
#     "standard_error": "0.6",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "Current asthma",
#     "sample_size": "619",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "Current asthma",
#     "response": "Yes",
#     "percent": "44.6",
#     "standard_error": "2.3",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "Current asthma",
#     "response": "No",
#     "percent": "43.5",
#     "standard_error": "2.3",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "Current asthma",
#     "response": "Do not know",
#     "percent": "3.3",
#     "standard_error": "1",
#     "significant_1": "0"
#   },
#   {
#     "round": "2",
#     "indicator": "Provider offers telemedicine",
#     "group": "Chronic conditions",
#     "subgroup": "Current asthma",
#     "response": "No usual place of care",
#     "percent": "8.6",
#     "standard_error": "1.4",
#     "significant_1": "0"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offers telemedicine",
#     "group": "Total",
#     "subgroup": "Total",
#     "sample_size": "2738",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offers telemedicine",
#     "group": "Total",
#     "subgroup": "Total",
#     "response": "Yes",
#     "percent": "31.7",
#     "standard_error": "1.2",
#     "significant_1": "1",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offers telemedicine",
#     "group": "Total",
#     "subgroup": "Total",
#     "response": "No",
#     "percent": "54.1",
#     "standard_error": "1.3",
#     "significant_1": "1",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offers telemedicine",
#     "group": "Total",
#     "subgroup": "Total",
#     "response": "Do not know",
#     "percent": "3.9",
#     "standard_error": "0.5",
#     "significant_1": "0",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offers telemedicine",
#     "group": "Total",
#     "subgroup": "Total",
#     "response": "No usual place of care",
#     "percent": "10.2",
#     "standard_error": "1",
#     "significant_1": "0",
#     "significant_2": "0"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "18-44 years",
#     "sample_size": "1007",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "18-44 years",
#     "response": "Yes",
#     "percent": "27.8",
#     "standard_error": "1.7",
#     "significant_1": "0",
#     "significant_2": "0"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "18-44 years",
#     "response": "No",
#     "percent": "49.8",
#     "standard_error": "2.2",
#     "significant_1": "0",
#     "significant_2": "0"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "18-44 years",
#     "response": "Do not know",
#     "percent": "5.9",
#     "standard_error": "1",
#     "significant_1": "0",
#     "significant_2": "0"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "18-44 years",
#     "response": "No usual place of care",
#     "percent": "16.5",
#     "standard_error": "1.9",
#     "significant_1": "0",
#     "significant_2": "0"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "45-64 years",
#     "sample_size": "892",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "45-64 years",
#     "response": "Yes",
#     "percent": "34",
#     "standard_error": "2",
#     "significant_1": "1",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "45-64 years",
#     "response": "No",
#     "percent": "56.8",
#     "standard_error": "2.1",
#     "significant_1": "1",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "45-64 years",
#     "response": "Do not know",
#     "percent": "3",
#     "standard_error": "0.9",
#     "significant_1": "0",
#     "significant_2": "0"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "45-64 years",
#     "response": "No usual place of care",
#     "percent": "6.2",
#     "standard_error": "1",
#     "significant_1": "0",
#     "significant_2": "0"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "65 years and over",
#     "sample_size": "839",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "65 years and over",
#     "response": "Yes",
#     "percent": "37.1",
#     "standard_error": "2.1",
#     "significant_1": "1",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offers telemedicine",
#     "group": "Age group",
#     "subgroup": "65 years and over",
#     "response": "No",
#     "percent": "59.7",
#     "standard_error": "2.2",
# ...
#     "percent": "100"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Race/Hispanic origin",
#     "subgroup": "Hispanic",
#     "response": "Yes",
#     "percent": "16.6",
#     "standard_error": "4.5",
#     "significant_1": "0",
#     "significant_2": "0"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Race/Hispanic origin",
#     "subgroup": "Hispanic",
#     "response": "No",
#     "percent": "40.7",
#     "standard_error": "5.4",
#     "significant_1": "1",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Race/Hispanic origin",
#     "subgroup": "Hispanic",
#     "response": "Do not know",
#     "suppression": "*"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Race/Hispanic origin",
#     "subgroup": "Hispanic",
#     "response": "No usual place of care",
#     "percent": "34.1",
#     "standard_error": "5.3",
#     "significant_1": "1",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Sex",
#     "subgroup": "Male",
#     "sample_size": "526",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Sex",
#     "subgroup": "Male",
#     "response": "Yes",
#     "percent": "18.8",
#     "standard_error": "2.4",
#     "significant_1": "1",
#     "significant_2": "0"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Sex",
#     "subgroup": "Male",
#     "response": "No",
#     "percent": "43.9",
#     "standard_error": "3.2",
#     "significant_1": "1",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Sex",
#     "subgroup": "Male",
#     "response": "Do not know",
#     "percent": "9.2",
#     "standard_error": "2.4",
#     "significant_1": "0",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Sex",
#     "subgroup": "Male",
#     "response": "No usual place of care",
#     "percent": "28",
#     "standard_error": "2.8",
#     "significant_1": "1",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Sex",
#     "subgroup": "Female",
#     "sample_size": "642",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Sex",
#     "subgroup": "Female",
#     "response": "Yes",
#     "percent": "20",
#     "standard_error": "2",
#     "significant_1": "1",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Sex",
#     "subgroup": "Female",
#     "response": "No",
#     "percent": "51.8",
#     "standard_error": "2.7",
#     "significant_1": "1",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Sex",
#     "subgroup": "Female",
#     "response": "Do not know",
#     "percent": "7.1",
#     "standard_error": "1.6",
#     "significant_1": "1",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Sex",
#     "subgroup": "Female",
#     "response": "No usual place of care",
#     "percent": "21.1",
#     "standard_error": "2.5",
#     "significant_1": "1",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Education",
#     "subgroup": "High school graduate or less",
#     "sample_size": "251",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Education",
#     "subgroup": "High school graduate or less",
#     "response": "Yes",
#     "percent": "17.6",
#     "standard_error": "3",
#     "significant_1": "0",
#     "significant_2": "0"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Education",
#     "subgroup": "High school graduate or less",
#     "response": "No",
#     "percent": "43.1",
#     "standard_error": "4.1",
#     "significant_1": "1",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Education",
#     "subgroup": "High school graduate or less",
#     "response": "Do not know",
#     "suppression": "*"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Education",
#     "subgroup": "High school graduate or less",
#     "response": "No usual place of care",
#     "percent": "32.1",
#     "standard_error": "4",
#     "significant_1": "1",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Education",
#     "subgroup": "Some college",
#     "sample_size": "583",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Education",
#     "subgroup": "Some college",
#     "response": "Yes",
#     "percent": "22.7",
#     "standard_error": "2.6",
#     "significant_1": "1",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Education",
#     "subgroup": "Some college",
#     "response": "No",
#     "percent": "49.7",
#     "standard_error": "3.1",
#     "significant_1": "1",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Education",
#     "subgroup": "Some college",
#     "response": "Do not know",
#     "percent": "7.2",
#     "standard_error": "1.4",
#     "significant_1": "1",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Education",
#     "subgroup": "Some college",
#     "response": "No usual place of care",
#     "percent": "20.4",
#     "standard_error": "2.3",
#     "significant_1": "1",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Education",
#     "subgroup": "Bachelor's degree or above",
#     "sample_size": "334",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Education",
#     "subgroup": "Bachelor's degree or above",
#     "response": "Yes",
#     "percent": "18.2",
#     "standard_error": "2.5",
#     "significant_1": "0",
#     "significant_2": "0"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Education",
#     "subgroup": "Bachelor's degree or above",
#     "response": "No",
#     "percent": "53.4",
#     "standard_error": "3.6",
#     "significant_1": "1",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Education",
#     "subgroup": "Bachelor's degree or above",
#     "response": "Do not know",
#     "percent": "10.4",
#     "standard_error": "1.5",
#     "significant_1": "1",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Education",
#     "subgroup": "Bachelor's degree or above",
#     "response": "No usual place of care",
#     "percent": "18",
#     "standard_error": "2.5",
#     "significant_1": "1",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Urbanization",
#     "subgroup": "Metropolitan",
#     "sample_size": "1021",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Urbanization",
#     "subgroup": "Metropolitan",
#     "response": "Yes",
#     "percent": "18.8",
#     "standard_error": "1.8",
#     "significant_1": "1",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Urbanization",
#     "subgroup": "Metropolitan",
#     "response": "No",
#     "percent": "48.4",
#     "standard_error": "2.2",
#     "significant_1": "1",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Urbanization",
#     "subgroup": "Metropolitan",
#     "response": "Do not know",
#     "percent": "8.7",
#     "standard_error": "1.5",
#     "significant_1": "1",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Urbanization",
#     "subgroup": "Metropolitan",
#     "response": "No usual place of care",
#     "percent": "24.1",
#     "standard_error": "1.9",
#     "significant_1": "1",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Urbanization",
#     "subgroup": "Non-Metropolitan",
#     "sample_size": "147",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Urbanization",
#     "subgroup": "Non-Metropolitan",
#     "response": "Yes",
#     "percent": "24.8",
#     "standard_error": "4.2",
#     "significant_1": "1",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Urbanization",
#     "subgroup": "Non-Metropolitan",
#     "response": "No",
#     "percent": "45.6",
#     "standard_error": "5.4",
#     "significant_1": "1",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Urbanization",
#     "subgroup": "Non-Metropolitan",
#     "response": "Do not know",
#     "suppression": "*"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Urbanization",
#     "subgroup": "Non-Metropolitan",
#     "response": "No usual place of care",
#     "percent": "26.5",
#     "standard_error": "6.9",
#     "significant_1": "1",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Chronic conditions",
#     "subgroup": "One or more chronic conditions",
#     "sample_size": "742",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Chronic conditions",
#     "subgroup": "One or more chronic conditions",
#     "response": "Yes",
#     "percent": "23.9",
#     "standard_error": "2.4",
#     "significant_1": "1",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Chronic conditions",
#     "subgroup": "One or more chronic conditions",
#     "response": "No",
#     "percent": "56.2",
#     "standard_error": "2.9",
#     "significant_1": "1",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Chronic conditions",
#     "subgroup": "One or more chronic conditions",
#     "response": "Do not know",
#     "percent": "7.8",
#     "standard_error": "2",
#     "significant_1": "0",
#     "significant_2": "0"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Chronic conditions",
#     "subgroup": "One or more chronic conditions",
#     "response": "No usual place of care",
#     "percent": "12",
#     "standard_error": "1.9",
#     "significant_1": "1",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Chronic conditions",
#     "subgroup": "Diagnosed diabetes",
#     "sample_size": "192",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Chronic conditions",
#     "subgroup": "Diagnosed diabetes",
#     "response": "Yes",
#     "percent": "22.8",
#     "standard_error": "3.4",
#     "significant_1": "0",
#     "significant_2": "0"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Chronic conditions",
#     "subgroup": "Diagnosed diabetes",
#     "response": "No",
#     "percent": "63.7",
#     "standard_error": "4.8",
#     "significant_1": "0",
#     "significant_2": "0"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Chronic conditions",
#     "subgroup": "Diagnosed diabetes",
#     "response": "Do not know",
#     "suppression": "*"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Chronic conditions",
#     "subgroup": "Diagnosed diabetes",
#     "response": "No usual place of care",
#     "suppression": "*"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Chronic conditions",
#     "subgroup": "Diagnosed hypertension",
#     "sample_size": "456",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Chronic conditions",
#     "subgroup": "Diagnosed hypertension",
#     "response": "Yes",
#     "percent": "25.4",
#     "standard_error": "3",
#     "significant_1": "1",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Chronic conditions",
#     "subgroup": "Diagnosed hypertension",
#     "response": "No",
#     "percent": "56.9",
#     "standard_error": "3.5",
#     "significant_1": "1",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Chronic conditions",
#     "subgroup": "Diagnosed hypertension",
#     "response": "Do not know",
#     "suppression": "*"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Chronic conditions",
#     "subgroup": "Diagnosed hypertension",
#     "response": "No usual place of care",
#     "percent": "11.2",
#     "standard_error": "2.3",
#     "significant_1": "1",
#     "significant_2": "1"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Chronic conditions",
#     "subgroup": "Current asthma",
#     "sample_size": "118",
#     "response": "Total",
#     "percent": "100"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Chronic conditions",
#     "subgroup": "Current asthma",
#     "response": "Yes",
#     "percent": "27.3",
#     "standard_error": "6.6",
#     "significant_1": "0",
#     "significant_2": "0"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Chronic conditions",
#     "subgroup": "Current asthma",
#     "response": "No",
#     "percent": "53",
#     "standard_error": "6.4",
#     "significant_1": "0",
#     "significant_2": "0"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Chronic conditions",
#     "subgroup": "Current asthma",
#     "response": "Do not know",
#     "suppression": "*"
#   },
#   {
#     "round": "3",
#     "indicator": "Provider offered telemedicine prior to pandemic",
#     "group": "Chronic conditions",
#     "subgroup": "Current asthma",
#     "response": "No usual place of care",
#     "suppression": "*"
#   }
# ]

# %%
import pandas as pd
import numpy as np

telemed = pd.DataFrame(data)

# %%
telemed.head()
# Out:
#   round                     indicator  group subgroup sample_size  \
# 0     1  Provider offers telemedicine  Total    Total        6786
# 1     1  Provider offers telemedicine  Total    Total         NaN
# 2     1  Provider offers telemedicine  Total    Total         NaN
# 3     1  Provider offers telemedicine  Total    Total         NaN
# 4     1  Provider offers telemedicine  Total    Total         NaN
#
#                  response percent standard_error suppression significant_1  \
# 0                   Total     100            NaN         NaN           NaN
# 1                     Yes    36.6            0.8         NaN           NaN
# 2                      No    46.9            0.8         NaN           NaN
# 3             Do not know     5.2            0.4         NaN           NaN
# 4  No usual place of care    11.3            0.7         NaN           NaN
#
#   significant_2
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
print("Original columns:", telemed.columns.tolist())

# Rename the 'round' column to 'date_range_category'
telemed = telemed.rename(columns={'round': 'date_range_category'})
# Out:
# Original columns: ['round', 'indicator', 'group', 'subgroup', 'sample_size', 'response', 'percent', 'standard_error', 'suppression', 'significant_1', 'significant_2']

# %%
print("Updated columns:", telemed.columns.tolist())
display(telemed.head())
# Out:
# Updated columns: ['date_range_category', 'indicator', 'group', 'subgroup', 'sample_size', 'response', 'percent', 'standard_error', 'suppression', 'significant_1', 'significant_2']
#   date_range_category                     indicator  group subgroup  \
# 0                   1  Provider offers telemedicine  Total    Total
# 1                   1  Provider offers telemedicine  Total    Total
# 2                   1  Provider offers telemedicine  Total    Total
# 3                   1  Provider offers telemedicine  Total    Total
# 4                   1  Provider offers telemedicine  Total    Total
#
#   sample_size                response percent standard_error suppression  \
# 0        6786                   Total     100            NaN         NaN
# 1         NaN                     Yes    36.6            0.8         NaN
# 2         NaN                      No    46.9            0.8         NaN
# 3         NaN             Do not know     5.2            0.4         NaN
# 4         NaN  No usual place of care    11.3            0.7         NaN
#
#   significant_1 significant_2
# 0           NaN           NaN
# 1           NaN           NaN
# 2           NaN           NaN
# 3           NaN           NaN
# 4           NaN           NaN

# %%
#Drop last 4 columns
telemed = telemed.iloc[:, :-4]

# %%
#Drop sample_size
telemed = telemed.drop(columns=['sample_size'])
display(telemed.head())
telemed.to_csv('telemedicine.csv', index=False)
# Out:
#   date_range_category                     indicator  group subgroup  \
# 0                   1  Provider offers telemedicine  Total    Total
# 1                   1  Provider offers telemedicine  Total    Total
# 2                   1  Provider offers telemedicine  Total    Total
# 3                   1  Provider offers telemedicine  Total    Total
# 4                   1  Provider offers telemedicine  Total    Total
#
#                  response percent
# 0                   Total     100
# 1                     Yes    36.6
# 2                      No    46.9
# 3             Do not know     5.2
# 4  No usual place of care    11.3

# %%
telemed_no = telemed[telemed['indicator'] == 'Provider offers telemedicine'][telemed['response'] == 'No'][telemed['subgroup'] == 'Total']
display(telemed_no.head())
# Out:
# /tmp/ipykernel_60747/3647151284.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   telemed_no = telemed[telemed['indicator'] == 'Provider offers telemedicine'][telemed['response'] == 'No'][telemed['subgroup'] == 'Total']
# /tmp/ipykernel_60747/3647151284.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   telemed_no = telemed[telemed['indicator'] == 'Provider offers telemedicine'][telemed['response'] == 'No'][telemed['subgroup'] == 'Total']
#     date_range_category                     indicator  group subgroup  \
# 2                     1  Provider offers telemedicine  Total    Total
# 97                    2  Provider offers telemedicine  Total    Total
# 192                   3  Provider offers telemedicine  Total    Total
#
#     response percent
# 2         No    46.9
# 97        No      48
# 192       No    54.1

# %%
#Recreate telemed_no table with date ranges in place of categories
define_date_range = {
    '1': '2020-06-09 to 2020-07-06',
    '2': '2020-08-03 to 2020-08-20',
    '3': '2021-05-17 to 2021-06-30'}

telemed_no['date_range_category'] = telemed_no['date_range_category'].map(define_date_range)
display(telemed_no.head())
# Out:
#           date_range_category                     indicator  group subgroup  \
# 2    2020-06-09 to 2020-07-06  Provider offers telemedicine  Total    Total
# 97   2020-08-03 to 2020-08-20  Provider offers telemedicine  Total    Total
# 192  2021-05-17 to 2021-06-30  Provider offers telemedicine  Total    Total
#
#     response percent
# 2         No    46.9
# 97        No      48
# 192       No    54.1

# %%
telemed_yes = telemed[telemed['indicator'] == 'Provider offers telemedicine'][telemed['response'] == 'Yes'][telemed['subgroup'] == 'Total']
display(telemed_yes.head())
# Out:
# /tmp/ipykernel_60747/417946074.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   telemed_yes = telemed[telemed['indicator'] == 'Provider offers telemedicine'][telemed['response'] == 'Yes'][telemed['subgroup'] == 'Total']
# /tmp/ipykernel_60747/417946074.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   telemed_yes = telemed[telemed['indicator'] == 'Provider offers telemedicine'][telemed['response'] == 'Yes'][telemed['subgroup'] == 'Total']
#     date_range_category                     indicator  group subgroup  \
# 1                     1  Provider offers telemedicine  Total    Total
# 96                    2  Provider offers telemedicine  Total    Total
# 191                   3  Provider offers telemedicine  Total    Total
#
#     response percent
# 1        Yes    36.6
# 96       Yes    37.1
# 191      Yes    31.7

# %%
#Recreate telemed_yes table with date ranges in place of categories
define_date_range = {
    '1': '2020-06-09 to 2020-07-06',
    '2': '2020-08-03 to 2020-08-20',
    '3': '2021-05-17 to 2021-06-30'}

telemed_yes['date_range_category'] = telemed_yes['date_range_category'].map(define_date_range)
display(telemed_yes.head())
# Out:
#           date_range_category                     indicator  group subgroup  \
# 1    2020-06-09 to 2020-07-06  Provider offers telemedicine  Total    Total
# 96   2020-08-03 to 2020-08-20  Provider offers telemedicine  Total    Total
# 191  2021-05-17 to 2021-06-30  Provider offers telemedicine  Total    Total
#
#     response percent
# 1        Yes    36.6
# 96       Yes    37.1
# 191      Yes    31.7

# %%
telemed.describe(include="all")
# Out:
#        date_range_category                     indicator  \
# count                  798                           798
# unique                   3                             3
# top                      1  Provider offers telemedicine
# freq                   266                           285
#
#                        group subgroup response percent
# count                    798      798      798     775
# unique                     7       19        6     370
# top     Race/Hispanic origin    Total    Total     100
# freq                     168       42      171     171

# %%
telemed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 798 entries, 0 to 797
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   date_range_category  798 non-null    object
#  1   indicator            798 non-null    object
#  2   group                798 non-null    object
#  3   subgroup             798 non-null    object
#  4   response             798 non-null    object
#  5   percent              775 non-null    object
# dtypes: object(6)
# memory usage: 37.5+ KB

# %%
telemed = telemed.replace(r'^\s*$', np.nan, regex=True)
telemed.isnull().sum()
# Out:
# date_range_category     0
# indicator               0
# group                   0
# subgroup                0
# response                0
# percent                23
# dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load Google Symptom Search Data
df1 = pd.read_csv('/content/drive/MyDrive/bq-results-20260425-185741-1777143487579/bq-results-20260425-185741-1777143487579.csv')
df1.head()
# Out:
#   country_region        date                   symptom  value  \
# 0  United States  2020-07-02  symptom_dry_eye_syndrome   0.59
# 1  United States  2020-07-04          symptom_insomnia   2.60
# 2  United States  2020-06-23          symptom_ear_pain   0.68
# 3  United States  2020-06-23         symptom_heartburn   2.77
# 4  United States  2020-06-09         symptom_pneumonia   0.72
#
#    date_range_category
# 0                  1.0
# 1                  1.0
# 2                  1.0
# 3                  1.0
# 4                  1.0

# %%
#Describe Google Symptom Search Data
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1222956 entries, 0 to 1222955
# Data columns (total 5 columns):
#  #   Column               Non-Null Count    Dtype
# ---  ------               --------------    -----
#  0   country_region       1222956 non-null  object
#  1   date                 1222956 non-null  object
#  2   symptom              1222956 non-null  object
#  3   value                1222956 non-null  float64
#  4   date_range_category  37136 non-null    float64
# dtypes: float64(2), object(3)
# memory usage: 46.7+ MB

# %%
#Convert date in Google Symptom Search Data to datetime
df1['date'] = pd.to_datetime(df1['date'])

# %%
#Describe Google Symptom Search Data
df1.describe(include="all")
# Out:
#        country_region                           date                  symptom  \
# count         1222956                        1222956                  1222956
# unique              1                            NaN                      422
# top     United States                            NaN  symptom_lightheadedness
# freq          1222956                            NaN                     2898
# mean              NaN  2021-11-10 11:59:59.999999744                      NaN
# min               NaN            2017-11-23 00:00:00                      NaN
# 25%               NaN            2019-11-17 00:00:00                      NaN
# 50%               NaN            2021-11-10 12:00:00                      NaN
# 75%               NaN            2023-11-05 00:00:00                      NaN
# max               NaN            2025-10-29 00:00:00                      NaN
# std               NaN                            NaN                      NaN
#
#                value  date_range_category
# count   1.222956e+06         37136.000000
# unique           NaN                  NaN
# top              NaN                  NaN
# freq             NaN                  NaN
# mean    1.023258e+00             2.193182
# min     1.000000e-02             1.000000
# 25%     1.600000e-01             1.000000
# 50%     3.500000e-01             2.500000
# 75%     9.000000e-01             3.000000
# max     1.033500e+02             3.000000
# std     2.371417e+00             0.877223

# %%
# Add column "Year" to Google Symptom Search Data
df1["year"] = df1["date"].dt.year

# %%
# Create pivot table to calculate Google symptom searches by year
df1.pivot_table(index='year', columns='symptom', values='value', aggfunc='sum')
# Out:
# symptom  symptom_abdominal_obesity  symptom_abdominal_pain  symptom_acne  \
# year
# 2017                         63.17                  153.71        269.31
# 2018                        741.42                 1398.27       2675.44
# 2019                        750.42                 1499.87       2881.50
# 2020                        844.98                 1466.46       3048.13
# 2021                        769.71                 1534.71       2726.26
# 2022                        664.34                 1588.89       2494.82
# 2023                        610.00                 1645.98       2579.42
# 2024                        548.96                 1564.02       2533.15
# 2025                        484.45                 1313.12       2093.54
#
# symptom  symptom_actinic_keratosis  symptom_acute_bronchitis  \
# year
# 2017                          8.89                     24.44
# 2018                        106.17                    151.25
# 2019                        115.76                    167.43
# 2020                        112.93                    120.02
# 2021                        118.90                    121.50
# 2022                        130.02                    159.96
# 2023                        128.23                    164.36
# 2024                        121.46                    157.83
# 2025                        107.83                    116.40
#
# symptom  symptom_adrenal_crisis  symptom_ageusia  symptom_alcoholism  \
# year
# 2017                       3.45             1.38              149.43
# 2018                      33.83            12.52             1359.82
# 2019                      35.51            14.08             1460.51
# 2020                      41.32            52.19             1417.97
# 2021                      38.96            56.02             1424.24
# 2022                      37.92            29.81             1407.10
# 2023                      42.32            19.66             1389.31
# 2024                      52.41            17.49             1358.77
# 2025                      37.98            13.99             1068.32
#
# symptom  symptom_allergic_conjunctivitis  symptom_allergy  ...  \
# year                                                       ...
# 2017                                1.84           317.74  ...
# 2018                               23.17          3372.66  ...
# 2019                               25.87          3730.46  ...
# 2020                               23.26          3813.82  ...
# 2021                               23.23          4041.63  ...
# 2022                               26.88          4112.41  ...
# 2023                               32.86          4207.95  ...
# 2024                               30.13          4127.23  ...
# 2025                               24.40          3594.42  ...
#
# symptom  symptom_visual_acuity  symptom_vomiting  symptom_wart  \
# year
# 2017                      6.63            111.19         46.54
# 2018                     64.55            892.87        483.55
# 2019                     73.66            991.47        496.38
# 2020                     76.11            898.95        458.04
# 2021                     74.50            981.81        453.45
# 2022                     76.54           1054.25        439.49
# 2023                     74.70           1081.80        456.95
# 2024                     71.70           1049.10        433.34
# 2025                     60.91            942.66        383.64
#
# symptom  symptom_water_retention  symptom_weakness  symptom_weight_gain  \
# year
# 2017                        8.31             12.05                97.51
# 2018                       95.88            129.11              1019.43
# 2019                      103.92            138.66              1075.48
# 2020                       98.09            141.73              1083.67
# 2021                      101.11            144.66              1114.54
# 2022                       96.83            145.99              1060.52
# 2023                       95.80            141.79              1047.91
# 2024                       89.89            130.79               954.68
# 2025                       83.68            112.97               821.75
#
# symptom  symptom_wheeze  symptom_xeroderma  symptom_xerostomia  symptom_yawn
# year
# 2017               9.32              90.81               12.88          5.26
# 2018              77.43             719.95              122.99         49.37
# 2019              89.43             794.42              136.89         55.87
# 2020              94.05             946.98              146.63         60.37
# 2021              89.10             821.23              146.56         58.00
# 2022              95.81             819.58              148.40         56.25
# 2023              97.76             822.24              152.85         57.02
# 2024              92.16             796.57              153.87         52.86
# 2025              74.09             639.28              131.72         46.79
#
# [9 rows x 422 columns]

# %%
from pandas.core import groupby
df1.groupby("symptom")["value"].sum()
orderby = df1.groupby("symptom")["value"].sum().sort_values(ascending=False)
orderby
# Out:
# symptom
# symptom_pain                  95798.05
# symptom_infection             61055.91
# symptom_allergy               31318.32
# symptom_common_cold           28282.70
# symptom_diabetes              23729.56
#                                 ...
# symptom_angular_cheilitis       200.62
# symptom_crackles                199.80
# symptom_polydipsia              181.19
# symptom_burning_chest_pain      154.86
# symptom_shallow_breathing       140.75
# Name: value, Length: 422, dtype: float64

# %%
plt.figure(figsize=(5, 2.5))
sns.histplot(df1[
    (df1['symptom'] == "symptom_pain")]['value'], bins=10)
plt.title('US Pain Search Distribution ')
plt.xlabel('Relative Number of Searches')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
sns.boxplot(df1[
    (df1['symptom'] == "symptom_pain")]['value'])
plt.ylim(0, 100)
plt.title('US Pain Symptom Searches')
plt.ylabel('Relative Frequency of Searches')
# Out:
# Text(0, 0.5, 'Relative Frequency of Searches')

# %%
pain_data = df1[(df1['symptom'] == 'symptom_pain')][['date', 'value']].rename(columns={'value': 'Pain_Searches'})
anxiety_data= df1[(df1['symptom'] == 'symptom_anxiety')][['date', 'value']].rename(columns={'value': 'Anxiety_Searches'})

merged_data = pd.merge(pain_data, anxiety_data, on='date', how='inner')

plt.figure(figsize=(8, 4))
sns.scatterplot(data=merged_data, x='Anxiety_Searches', y='Pain_Searches')
plt.title('US Pain vs Anxiety Symptom Searches')
plt.xlabel('Anxiety Searches')
plt.ylabel('Pain Searches')
plt.grid(True)
plt.show()

# %%
import statsmodels.api as sm
pain_data = df1[(df1['symptom'] == 'symptom_pain')][['date', 'value']].rename(columns={'value': 'Pain_Searches'})
anxiety_data= df1[(df1['symptom'] == 'symptom_anxiety')][['date', 'value']].rename(columns={'value': 'Anxiety_Searches'})

merged_data = pd.merge(pain_data, anxiety_data, on='date', how='inner')
sns.regplot(data=merged_data, x='Anxiety_Searches', y='Pain_Searches')
plt.title('US Pain vs Anxiety Symptom Searches')
plt.xlabel('Anxiety Searches')
plt.ylabel('Pain Searches')
plt.grid(True)
plt.show()

# %%
pain_data = df1[(df1['symptom'] == 'symptom_pain')][['date', 'value']].rename(columns={'value': 'Pain_Searches'})
depression_data= df1[(df1['symptom'] == 'symptom_depression')][['date', 'value']].rename(columns={'value': 'Depression_Searches'})

merged_data = pd.merge(pain_data, depression_data, on='date', how='inner')

plt.figure(figsize=(8, 4))
sns.regplot(data=merged_data, x='Depression_Searches', y='Pain_Searches', ci=95)
plt.title('US Pain vs Depression Symptom Searches (95% CI)')
plt.xlabel('Depression Searches')
plt.ylabel('Pain Searches')
plt.grid(True)
plt.show()

# %%
pain_data = df1[(df1['symptom'] == 'symptom_pain')][['date', 'value']].rename(columns={'value': 'Pain_Searches'})
sleep_disorder_data= df1[(df1['symptom'] == 'symptom_sleep_disorder')][['date', 'value']].rename(columns={'value': 'Sleep_Disorder_Searches'})

merged_data = pd.merge(pain_data, sleep_disorder_data, on='date', how='inner')

plt.figure(figsize=(8, 4))
sns.regplot(data=merged_data, x='Sleep_Disorder_Searches', y='Pain_Searches', ci=95)
plt.title('US Pain vs Sleep Disorder Symptom Searches (95% CI)')
plt.xlabel('Sleep Disorder Searches')
plt.ylabel('Pain Searches')
plt.grid(True)
plt.show()

# %%
pain_data = df1[(df1['symptom'] == 'symptom_pain')][['date', 'value']].rename(columns={'value': 'Pain_Searches'})
obesity_data= df1[(df1['symptom'] == 'symptom_obesity')][['date', 'value']].rename(columns={'value': 'Obesity_Searches'})

merged_data = pd.merge(pain_data, obesity_data, on='date', how='inner')

plt.figure(figsize=(8, 4))
sns.regplot(data=merged_data, x='Obesity_Searches', y='Pain_Searches', ci=95)
plt.title('US Pain vs Obesity Symptom Searches (95% CI)')
plt.xlabel('Obesity Searches')
plt.ylabel('Pain Searches')
plt.grid(True)
plt.show()

# %%
symptom_sums = df1[df1['date_range_category'] != 'nan'].groupby(["date_range_category", "symptom"])["value"].sum()
max_searches_by_category = symptom_sums.groupby(level='date_range_category').idxmax()
result = symptom_sums.loc[max_searches_by_category]
display(result)
# Out:
# date_range_category  symptom
# 1.0                  symptom_pain     922.05
# 2.0                  symptom_pain     575.59
# 3.0                  symptom_pain    1540.91
# Name: value, dtype: float64

# %%
#Graph pain searches by category
pain_searches_by_category = df1[df1['symptom'] == "symptom_pain"].groupby('date_range_category')['value'].sum().reset_index()

plt.figure(figsize=(8, 4))
sns.barplot(data=pain_searches_by_category, x='date_range_category', y='value')
plt.title('Pain Searches by Date Range')
plt.xlabel('Date Range')
plt.ylabel('Total Pain Searches Value')

# Define the mapping for date ranges with newlines for wrapping
date_range_labels = {
    '1.0': '2020-06-09\nto 2020-07-06',
    '2.0': '2020-08-03\nto 2020-08-20',
    '3.0': '2021-05-17\nto 2021-06-30'
}

# Convert date_range_category to string for proper mapping
pain_searches_by_category['date_range_category'] = pain_searches_by_category['date_range_category'].astype(str)

# Apply the mapping to the x-axis tick labels, removing rotation for horizontal alignment
plt.xticks(ticks=range(len(pain_searches_by_category['date_range_category'])),
           labels=[date_range_labels.get(cat, cat) for cat in pain_searches_by_category['date_range_category']])

plt.tight_layout() # Adjust layout to prevent labels from being cut off
plt.show()

# %%
#Graph total Google symptom searches by date category
total_searches_by_category = df1.groupby('date_range_category')['value'].sum().reset_index()

plt.figure(figsize=(8, 5))
sns.barplot(data=total_searches_by_category, x='date_range_category', y='value')
plt.title('Total Searches by Date Range')
plt.xlabel('Date Range')
plt.ylabel('Total Searches Value')

# Define the mapping for date ranges with newlines for wrapping
date_range_labels = {
    '1.0': '2020-06-09\nto 2020-07-06',
    '2.0': '2020-08-03\nto 2020-08-20',
    '3.0': '2021-05-17\nto 2021-06-30'
}
# Convert date_range_category to string for proper mapping
total_searches_by_category['date_range_category'] = total_searches_by_category['date_range_category'].astype(str)

# Apply the mapping to the x-axis tick labels, removing rotation for horizontal alignment
plt.xticks(ticks=range(len(total_searches_by_category['date_range_category'])),
           labels=[date_range_labels.get(cat, cat) for cat in total_searches_by_category['date_range_category']])

plt.tight_layout() # Adjust layout to prevent labels from being cut off
plt.show()

# %%
df2 = pd.read_csv('/content/drive/MyDrive/bq-results-20260425-132419-1777124125607/bq-results-20260425-132419-1777124125607.csv')
df2.head()
# Out:
#                       indicator  group subgroup     response  percent  \
# 0  Provider offers telemedicine  Total    Total  Do not know      5.2
# 1  Provider offers telemedicine  Total    Total  Do not know      5.2
# 2  Provider offers telemedicine  Total    Total  Do not know      5.2
# 3  Provider offers telemedicine  Total    Total  Do not know      5.2
# 4  Provider offers telemedicine  Total    Total  Do not know      5.2
#
#   country_region        date                    symptom  value  \
# 0  United States  2020-06-09     symptom_blurred_vision   0.36
# 1  United States  2020-06-09          symptom_granuloma   0.15
# 2  United States  2020-06-09        symptom_indigestion   1.35
# 3  United States  2020-06-09  symptom_throat_irritation   0.14
# 4  United States  2020-06-09     symptom_sleep_disorder   2.14
#
#    date_range_category
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 408496 entries, 0 to 408495
# Data columns (total 10 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   indicator            408496 non-null  object
#  1   group                408496 non-null  object
#  2   subgroup             408496 non-null  object
#  3   response             408496 non-null  object
#  4   percent              408496 non-null  float64
#  5   country_region       408496 non-null  object
#  6   date                 408496 non-null  object
#  7   symptom              408496 non-null  object
#  8   value                408496 non-null  float64
#  9   date_range_category  408496 non-null  int64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 31.2+ MB

# %%
df2.describe(include="all")
# Out:
#                            indicator   group subgroup response        percent  \
# count                         408496  408496   408496   408496  408496.000000
# unique                             3       1        1        5            NaN
# top     Provider offers telemedicine   Total    Total      Yes            NaN
# freq                          148544  408496   408496   111408            NaN
# mean                             NaN     NaN      NaN      NaN      27.263636
# std                              NaN     NaN      NaN      NaN      19.608575
# min                              NaN     NaN      NaN      NaN       3.900000
# 25%                              NaN     NaN      NaN      NaN      11.300000
# 50%                              NaN     NaN      NaN      NaN      18.700000
# 75%                              NaN     NaN      NaN      NaN      46.900000
# max                              NaN     NaN      NaN      NaN      67.200000
#
#        country_region        date                         symptom  \
# count          408496      408496                          408496
# unique              1          88                             422
# top     United States  2020-06-09  symptom_hepatic_encephalopathy
# freq           408496        4642                             968
# mean              NaN         NaN                             NaN
# std               NaN         NaN                             NaN
# min               NaN         NaN                             NaN
# 25%               NaN         NaN                             NaN
# 50%               NaN         NaN                             NaN
# 75%               NaN         NaN                             NaN
# max               NaN         NaN                             NaN
#
#                 value  date_range_category
# count   408496.000000        408496.000000
# unique            NaN                  NaN
# top               NaN                  NaN
# freq              NaN                  NaN
# mean         1.031506             2.193182
# std          2.377703             0.877212
# min          0.020000             1.000000
# 25%          0.160000             1.000000
# 50%          0.360000             2.500000
# 75%          0.910000             3.000000
# max         37.390000             3.000000

# %%
df2 = df2.replace(r'^\s*$', np.nan, regex=True)
df2.isnull().sum()
# Out:
# indicator              0
# group                  0
# subgroup               0
# response               0
# percent                0
# country_region         0
# date                   0
# symptom                0
# value                  0
# date_range_category    0
# dtype: int64

# %%
telemed_yes['percent'] = pd.to_numeric(telemed_yes['percent'], errors='coerce')

plt.figure(figsize=(8, 5))
sns.barplot(data=telemed_yes, x='date_range_category', y='percent')
plt.title('Telemedicine = "Yes" by Date Range')
plt.xlabel('Date Range')
plt.ylabel('Percent Telemedicine = Yes')

plt.tight_layout() # Adjust layout to prevent labels from being cut off

# %%
telemed_no_data = telemed[
    (telemed['indicator'] == 'Provider offers telemedicine') &
    (telemed['response'] == 'No') &
    (telemed['subgroup'] == 'Total')
].copy()

telemed_no_data['percent'] = pd.to_numeric(telemed_no_data['percent'], errors='coerce')
telemed_no_data['date_range_category'] = pd.to_numeric(telemed_no_data['date_range_category'])

pain_searches_by_category = df2[
    (df2['symptom'] == 'symptom_pain') &
    (df2['indicator'] == 'Provider offers telemedicine') &
    (df2['subgroup'] == 'Total') &
    (df2['response'] == 'No')
].groupby('date_range_category')['value'].sum().reset_index()

merged_data_no = pd.merge(telemed_no_data, pain_searches_by_category, on='date_range_category', how='inner')
display(merged_data_no.head())
# Out:
#    date_range_category                     indicator  group subgroup response  \
# 0                    1  Provider offers telemedicine  Total    Total       No
# 1                    2  Provider offers telemedicine  Total    Total       No
# 2                    3  Provider offers telemedicine  Total    Total       No
#
#    percent    value
# 0     46.9   922.05
# 1     48.0   575.59
# 2     54.1  1540.91

# %%
plt.figure(figsize=(8, 6))
sns.regplot(data=merged_data_no, x='percent', y='value', ci=95)
plt.title('Relationship Between Telemedicine "No" Percent and Pain Searches')
plt.xlabel('Percent of Providers NOT Offering Telemedicine')
plt.ylabel('Total Pain Searches Value')
plt.grid(True)
plt.show()

# %%
telemed_yes_data = telemed[
    (telemed['indicator'] == 'Provider offers telemedicine') &
    (telemed['response'] == 'Yes') &
    (telemed['subgroup'] == 'Total')
].copy()

telemed_yes_data['percent'] = pd.to_numeric(telemed_yes_data['percent'], errors='coerce')
telemed_yes_data['date_range_category'] = pd.to_numeric(telemed_yes_data['date_range_category'])

pain_searches_by_category = df2[
    (df2['symptom'] == 'symptom_pain') &
    (df2['indicator'] == 'Provider offers telemedicine') &
    (df2['subgroup'] == 'Total') &
    (df2['response'] == 'Yes')
].groupby('date_range_category')['value'].sum().reset_index()

merged_data_yes = pd.merge(telemed_yes_data, pain_searches_by_category, on='date_range_category', how='inner')
display(merged_data_yes.head())
# Out:
#    date_range_category                     indicator  group subgroup response  \
# 0                    1  Provider offers telemedicine  Total    Total      Yes
# 1                    2  Provider offers telemedicine  Total    Total      Yes
# 2                    3  Provider offers telemedicine  Total    Total      Yes
#
#    percent    value
# 0     36.6   922.05
# 1     37.1   575.59
# 2     31.7  1540.91

# %%
plt.figure(figsize=(8, 6))
sns.regplot(data=merged_data_yes, x='percent', y='value', ci=95)
plt.title('Relationship Between "Telemedicine = Yes" Percent and Pain Searches')
plt.xlabel('Percent of Providers Offering Telemedicine (Yes)')
plt.ylabel('Total Pain Searches Value')
plt.grid(True)
plt.show()
